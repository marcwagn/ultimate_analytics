# %%
from tasks.tasks import track, _translate_coordinates
import os
import cv2

model_dir = os.getenv("MODEL_DATA_DIR", "./data/model")
model_path = os.path.join(model_dir, "best.pt")

video_path = "./data/uploads/mini_test.mp4"

video = cv2.VideoCapture(video_path)
total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

def update_progressbar(frame):
    print(f"YOLO object tracking for {video_path}: frame {frame}")

tracking_results = track(model_path=model_path, 
                         video_path=video_path, 
                         progressbar_callback=update_progressbar)

tracking_results_df = _translate_coordinates(tracking_results, total_frames=total_frames)
# Out:
# YOLO object tracking for ./data/uploads/mini_test.mp4: frame 1
# video 1/1 (frame 1/12) /home/mc/projects/ultimate_analytics/web-app/src/data/uploads/mini_test.mp4: 2176x3840 14 persons, 1 TLC, 1 TRC, 1 TEC, 1 TLF, 1 TRF, 1 TMB, 1 C, 3141.4ms
#    cls_name  team
# 0    person     1
# 1    person     1
# 2    person     1
# 3    person     1
# 4    person     0
# 5    person     0
# 6       TLF    -1
# 7    person     0
# 8       TMB    -1
# 9         C    -1
# 10   person     0
# 11      TRF    -1
# 12   person     1
# 13   person     1
# 14   person     0
# 15   person     0
# 16      TRC    -1
# 17      TLC    -1
# 18   person     0
# 19   person     1
# 20      TEC    -1
# YOLO object tracking for ./data/uploads/mini_test.mp4: frame 2
# video 1/1 (frame 2/12) /home/mc/projects/ultimate_analytics/web-app/src/data/uploads/mini_test.mp4: 2176x3840 14 persons, 1 TLC, 1 TRC, 1 TEC, 1 TLF, 1 TRF, 1 TMB, 1 C, 3964.5ms
#    cls_name  team
# 0    person     0
# 1    person     0
# ...

# %%
lst_tracking_results = list(tracking_results)
# Out:
# YOLO object tracking for ./data/uploads/mini_test.mp4: frame 1
# video 1/1 (frame 1/12) /home/mc/projects/ultimate_analytics/web-app/src/data/uploads/mini_test.mp4: 2176x3840 14 persons, 1 TLC, 1 TRC, 1 TEC, 1 TLF, 1 TRF, 1 TMB, 1 C, 3221.7ms
# YOLO object tracking for ./data/uploads/mini_test.mp4: frame 2
# video 1/1 (frame 2/12) /home/mc/projects/ultimate_analytics/web-app/src/data/uploads/mini_test.mp4: 2176x3840 14 persons, 1 TLC, 1 TRC, 1 TEC, 1 TLF, 1 TRF, 1 TMB, 1 C, 3066.5ms
# YOLO object tracking for ./data/uploads/mini_test.mp4: frame 3
# video 1/1 (frame 3/12) /home/mc/projects/ultimate_analytics/web-app/src/data/uploads/mini_test.mp4: 2176x3840 14 persons, 1 TLC, 1 TRC, 1 TEC, 1 TLF, 1 TRF, 1 TMB, 1 C, 3343.5ms
# YOLO object tracking for ./data/uploads/mini_test.mp4: frame 4
# video 1/1 (frame 4/12) /home/mc/projects/ultimate_analytics/web-app/src/data/uploads/mini_test.mp4: 2176x3840 14 persons, 1 TLC, 1 TRC, 1 TEC, 1 TLF, 1 TRF, 1 TMB, 1 C, 3082.0ms
# ...

# %%
for frame in range(len(lst_tracking_results)):
team_detector = TeamDetector(frame, lst_tracking_results)
